# %%
# %run template.py

# %%
import os 
filepath='a/b/c.txt'
os.path.split(filepath)
# Out:
# ('a/b', 'c.txt')

# %%
# Out:
#   Cell In[12], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax
